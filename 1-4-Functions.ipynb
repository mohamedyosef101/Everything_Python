# %% [markdown]
# <h1>Functions in Python</h1>

# %% [markdown]
# A function is a reusable block of code which performs operations specified in the function. They let you break down tasks and allow you to reuse your code in different programs.
#
# There are two types of functions :
#
# *   <b>Pre-defined functions</b>
# *   <b>User defined functions</b>

# %% [markdown]
# <h2 id="pre">Pre-defined functions</h2>

# %% [markdown]
# There are many pre-defined functions in Python, so let's start with the simple ones.

# %% [markdown]
# The <span style="color: #00a1ff">print()</span> function:

# %%
# Build-in function print()

album_ratings = [10.0, 8.5, 9.5, 7.0, 7.0, 9.5, 9.0, 9.5] 
print(album_ratings)

# %% [markdown]
# The <span style="color: #00a1ff">sum()</span> function adds all the  elements in a list or tuple:

# %%
# Use sum() to add every element in a list or tuple together

sum(album_ratings)

# %% [markdown]
# The <span style="color: #00a1ff">len()</span> function returns the length of a list or tuple:

# %%
# Show the length of the list or tuple

len(album_ratings)

# %% [markdown]
# <hr>
# <br>
# <h2>Using <span style="color: #00a1ff">If & Loops</span> in Functions</h2>

# %%
# Function example

def type_of_album(artist, album, year_released):
    
    print(artist, album, year_released)
    if year_released > 1980:
        return "Modern"
    else:
        return "Oldie"
    
x = type_of_album("Michael Jackson", "Thriller", 1980)
print(x)

# %%
#Compare Two Strings Directly using in operator
# add string
string= "Michael Jackson is the best"

# Define a funtion
def check_string(text):
    
# Use if else statement and 'in' operatore to compare the string
    if text in string:
        return 'String matched'
    else:
        return 'String not matched'

check_string("Michael Jackson is the best")

# %% [markdown]
# <hr>

# %% [markdown]
# <h2 id="default">Setting default argument values</h2>

# %%
# Example for setting param with default value

def isGoodRating(rating=4): 
    if(rating < 7):
        print("this album sucks it's rating is",rating)
        
    else:
        print("this album is good its rating is",rating)

# %%
# Test the value with default value and with input

isGoodRating()
isGoodRating(10)

# %% [markdown]
# <hr>
